# %%
import pandas as pd
import numpy as np
import string

# %%
df = pd.read_csv("cases.csv", encoding='latin-1')

# %%
def encodeDecode(df):
    for i in range(df.shape[0]):
        for j in range(df.shape[1]):
            if isinstance(df.iloc[i, j], str):
                df.iloc[i, j] = df.iloc[i, j].encode('ascii', 'ignore').decode("utf-8")

# %%
encodeDecode(df)

# %%
not np.isnan(df.iloc[0,6])
# Out:
# False

# %%
for i in df.index:
    if df.iloc[i,0].isupper() :
        df.iloc[i,0] = df.iloc[i,0].lower()

# %%
for i in df.index:
    if isinstance(df.iloc[i,6], str) and df.iloc[i,6].isupper() :
        df.iloc[i,6] = df.iloc[i,6].lower()

# %%
def printCase(case):
    for i in case.index:
        print(i.upper()+": ")
        if isinstance(case[i], str) :
            for point in case[i].split("."):
                print(point.strip())
        else:
            print(case[i])
        print(" ")

# %%
def printCases(df):
    for i in df.index:
        printCase(df.iloc[i,:])
        print("-"*70)

# %%
def searchCases(cases, case, by = "name"):
    
    for index, value in cases.iterrows():
        if by == "name" and case.lower() in value["name"].lower():
            printCase(value)
            print("-"*70)
        elif by == "description" and type(value["description"]) == str and case.lower() in value["description"].lower():
            printCase(value)
            print("-"*70)

# %%
df
# Out:
#                                                  name  \
# 0                   Balfour v Balfour (1919) 2 KB 571
# 1                      Cohen v Cohen (1929) 42 CLR 91
# 2               Merritt v Merritt (1970) 2 All ER 760
# 3                             scarborough v sturzaker
# 4                               hamilton v lethbridge
# 5               placer development ltd v commonwealth
# 6   pharmaceutical society of great britain v boot...
# 7                              partridge v crittenden
# 8                                   masters v cameron
# 9                                   henthorn v fraser
# 10                                          brinkibon
# 11                                    thomas v thomas
# 12                                     stilk v myrick
# 13                        musumeci v winadell pty ltd
# 14        ermogenous v greek orthodox community of sa
# 15  esso petroleum v commissioner of customs & excise
# 16                   carlill v carbolic smoke ball co
# 17                                     price v easton
# 18                           coulls v bagots executor
# 19                              lestrange v f graucob
# 20                                    causer v browne
# 21                          sydney corporation v west
# 22                      olley v marlborough court ltd
# 23                       van den esschert v chappell
# 24                         oscar chess ltd v williams
# 25                                   handbury v nolan
# 26                        secured income v st martins
# 27                                   breen v williams
# 28                                     varley v whipp
# 29                  australian knitting mills v grant
# ..                                                ...
# 42        maritime national fish ltd v ocean trawlers
# 43                           radford v de froberville
# 44               tabcorp holdings v bowen investments
# 45                             koufos v czarnikow ltd
# 46                                 hadley v baxendale
# 47          mcrae v commonwealth disposals commission
# 48                           baltic shipping v dillon
# 49              burns v man automotive (aust) pty ltd
# 50                     associated newspapers v bancks
# 51                                holland v wiltshire
# 52                              hochster v de la tour
# 53                                      bettini v gye
# 54                                    cehave v bremer
# 55                                       dougan v ley
# 56                 jc williamson v lukey & mulholland
# 57                 buckenara v hawthorn football club
# 58                                    lumley v wagner
# 59                                 barton v armstrong
# 60       north ocean shipping v hyundai constructions
# 61                                  allcard v skinner
# 62                                 johnson v buttress
# 63              commercial bank of australia v amadio
# 64                   garcia v national australia bank
# 65                     leaf v international galleries
# 66                            great peace v tsavliris
# 67                               raffles v wichelhaus
# 68                                   taylor v johnson
# 69                                     alati v kruger
# 70                          lindner v murdocks garage
# 71                         fitzgerald v fj leonhardt
#
#                                                  fact  \
# 0   Plaintiff alleged husband promised to pay 30 p...
# 1   Plaintiff alleged defendant promised to pay he...
# 2   Husband and wife married, got a building plot ...
# 3   Scarborough purchased a bicycle from Sturzaker...
# 4   L (a minor) entered into a five year contract,...
# 5   The Cth government promised to pay PD a subsid...
# 6   Boots ran a self-service chemist. Non-prescrip...
# 7   P put an advertisement in a newspaper which st...
# 8   parties signed a written memorandum whereby C ...
# 9   F offered to sell certain houses to H. H was g...
# 10  B (based in London) wished to purchase machine...
# 11  Mr T expressed a desire that, should he die fi...
# 12  When two sailors deserted a voyage, the captai...
# 13  M leased a fruit and vegetable shop from W. at...
# 14  E was recruited by the GOCoSA from the US to s...
# 15  E ran a marketing promotion.  It promised to g...
# 16                                                NaN
# 17  A builder owed money to P, which the builder w...
# 18  Mr C entered into a contract with ON: Mr C pro...
# 19  L purchased a cigarette machine from F. L sign...
# 20  C took a dress to B for dry cleaning. He was h...
# 21  W drove into a carpark and took a ticket hande...
# 22  When Mr and Mrs O arrived at the Marlborough C...
# 23  Before V purchased Cs house, C made an oral pr...
# 24  W offered to trade in his mothers car to a car...
# 25  an auctioneer offered a cow for sale at auctio...
# 26  SI sold a large office block to SM. $170,000 r...
# 27  W was Bs doctor. B asked W to hand over her me...
# 28  V and W entered into a contract under which V ...
# 29  G purchased underwear manufactured by AKM. Aft...
# ..                                                ...
# 42  MNF chartered a trawler from OT, which MNF int...
# 43  R owned two blocks of land. He sold one to F o...
# 44  B leased a building to T for ten years. It was...
# 45  C chartered Ks ship to carry cargo. The ship r...
# 46  H engaged B to deliver a broken mill shaft to ...
# 47  CDC invited tenders for the purchase of an oil...
# 48  Mrs D was a passenger on a cruise ship who sou...
# 49  MAN supplied a defective commercial vehicle to...
# 50                                                NaN
# 51  W sold land to H. The contract nominated a dat...
# 52  D engaged H as a courier. Three weeks before t...
# 53  B, a singer, contracted to sing for G (a promo...
# 54  B sold citrus pellets to C. The contract requi...
# 55  D sold a taxi, together with its operating lic...
# 56  W operated three theatres in Melbourne. W leas...
# 57  B was contracted to play football for HFCB pro...
# 58  W contracted to sing in Ls theatre (first prom...
# 59                                                NaN
# 60  H agreed to build a tanker for NOS for a fixed...
# 61  A joined religious order and took a vow of pov...
# 62  B was an elderly man, excitable, emotional, un...
# 63  Mr and Mrs A were 76 and 71 respectively. both...
# 64  In 1987 Mrs G signed, at her husbands request,...
# 65  L saw a painting of Salisbury Cathedral that I...
# 66                                                NaN
# 67  W agreed to buy cotton from R. The cotton was ...
# 68  J entered into a contract with T for the sale ...
# 69  A told K that As business made sales of 100 pe...
# 70                                                NaN
# 71                                                NaN
#
#                                                 issue  \
# 0                  Later they separated and divorced.
# 1                                     They separated.
# 2                                                 NaN
# 3   given Scarborough already owned a bike (the on...
# 4   Was the contract legally binding?  Was the con...
# 5   Had the government made a legally binding prom...
# 6   Were drugs selected by the customer sold to th...
# 7   Was the advertisement an offer or an invitstio...
# 8   Was the signed memorandum a non-binding argeem...
# 9   Had H accepted the offer before Fs attempt to ...
# 10  Where was the contract formed? In which countr...
# 11  Had Mrs T provided sufficient consideration to...
# 12  Had the crew given consideration for the capta...
# 13  Had M provided sufficient consideration to sup...
# 14  Did the parties intend their agreement to be e...
# 15  Did Esso and its customers intend the agreemen...
# 16  Was the promise to pay the reward contained in...
# 17  Was P entitled to enforce Es promise to the bu...
# 18  Did Mrs C have a legally enforceable right to ...
# 19  Was L bound by the term that excluded implied ...
# 20  Did the statement on the docket excludes Bs li...
# 21  Did the statement on the ticket become a term ...
# 22  Was the statements in the notice terms of the ...
# 23         Was the oral promise part of the contract?
# 24  Was Ws statement that the car was a 1948 model...
# 25  was the auctioneers statement a contractual pr...
# 26  Had SM breached the implied duty of co-operati...
# 27  Do doctor/patient contracts include an implied...
# 28  Did the contract include an implied condition ...
# 29         Was the underwear of merchantable quality?
# ..                                                ...
# 42  Did the fact that MNF was not allocated enough...
# 43       What was the appropriate measure of damages?
# 44  Was B entitled to recover the full cost of res...
# 45  Was C entitled to damages to compensate for th...
# 46   Was H entitled to compensation for lost profits?
# 47  Could McRae recover damages to compensate for ...
# 48  Was D entitled to damages for distress and dis...
# 49  Had B taken reasonable steps to mitigate his l...
# 50  Was the promise to publish on the front page o...
# 51  Was the time specified as condition?. Did W ha...
# 52  Could H terminate the contract and, in turn, s...
# 53  Was the promise to attend rehearsal a conditio...
# 54  Was C entitled to reject the goods and termina...
# 55      Was specific performance an available remedy?
# 56      Was specific performance an available remedy?
# 57  Is an injunction preventing breach of the prom...
# 58  Would an injunction be granted to restrain bre...
# 59  Could the sale contract be set aside on the ba...
# 60  Was NOS bound to pay the increased price?. Did...
# 61  Could the gift transaction be avoided on the b...
# 62  Could the transfer be set aside on the grounds...
# 63                   Could CBA enforce the guarantee?
# 64                      Was G bound by the guarantee?
# 65  Could the contract be avoided on the basis tha...
# 66  Both parties assumed that the Great Peace was ...
# 67  Did R and W owe each other contractual obligat...
# 68  Did Js mistake allow her to set aside the cont...
# 69              Was K entitled to avoid the contract?
# 70              Was the restraint clause enforceable?
# 71  Was the contract between F and FJL impliedly p...
#
#                                              decision  \
# 0   Judge decided in favour of plaintiff, defendan...
# 1   Same ratio decidendi as above, binding on Aust...
# 2   when married persons whose relationship has al...
# 3                   The contract was legally binding.
# 4                    The contract was legally binding
# 5   A majority of the High Court held that governm...
# 6              Display of goods = invitation to treat
# 7   The advertisement was an invitation to enter i...
# 8   The memorandum was a non-binding preliminary a...
# 9   Acceptance was effective as soon as H posted t...
# 10  The postal acceptance rule should not be exten...
# 11  Mrs T had provided consideration.  She was ent...
# 12  The crew had merely performed an existing lega...
# 13  M promised to do no more than perform its exis...
# 14  The agreement was intended to be legally bindi...
# 15  The terms of the promotion were intended to be...
# 16                                 yes. Yes. Yes. Yes
# 17          P was not entitled to enforce the promise
# 18  Mrs C had not obtained enforceable rights unde...
# 19  L was bound by the terms of the document she s...
# 20       The statement was not a term of the contract
# 21  The statement on the ticket was a term of the ...
# 22  The statement in the notice was not a term of ...
# 23           Contract was partly-written, partly-oral
# 24  The description of the car was a (mis)represen...
# 25  The auctioneers statement was promissory, and ...
# 26  St M had not breached the implied duty of co-o...
# 27  There is no implied term in a doctor/patient c...
# 28  The contract contained an implied condition th...
# 29  Even if familiar with the fault, most people w...
# ..                                                ...
# 42               The contract had not been frustrated
# 43  R could recover damages measured by reference ...
# 44  B was entitled to recover the full costs of re...
# 45  Damages were payable to compensate for the los...
# 46  H was not entitled to compensation for lost pr...
# 47  McRae was entitled to recover the costs of the...
# 48  D could recover damages for loss in the form o...
# 49    B had taken adequate steps to mitigate the loss
# 50  The promise to publish on the front page of th...
# 51  Time for performance was held to be a conditio...
# 52  H could terminate the contract (and sue for da...
# 53  The rehearsal promise was a warranty. Thus, G ...
# 54  C could not reject the goods and terminate the...
# 55  L was entitled to an order of specific perform...
# 56   Specific performance was not an available remedy
# 57                          The injunction was issued
# 58  The court issued an injunction which prevented...
# 59                    The contract could be set aside
# 60  Hs conduct amounted to duress. However, NOS re...
# 61  The transaction could not be avoided on the ba...
# 62  The gift could be set aside on the basis of un...
# 63                        The guarantee was set aside
# 64                        The guarantee was set aside
# 65  The mistake did not justify setting the contra...
# 66                The contract could not be set aside
# 67        No binding contract had come into existence
# 68  The contract was set aside on the basis of uni...
# 69                        K could cancel the contract
# 70             The restraint clause was unenforceable
# 71  The contract was enforceable despite the fact ...
#
#                                                reason    year  \
# 0   When married persons enter into domestic agree...  1919.0
# 1   Same ratio decidendi as above, binding on Aust...  1929.0
# 2   MerrittOs case does not mean that Balfour and ...  1970.0
# 3   Given the distance Scarborough lived from his ...  1905.0
# 4   Although some stipulations in the contract ben...  1912.0
# 5   [A] promise to pay an unspecified amount of mo...  1969.0
# 6   Customer makes the offer to the cashier. Cashi...  1953.0
# 7   Unless advertisements come from manufacturers,...  1968.0
# 8   The parties do not intend to make a binding ag...  1954.0
# 9   Where the circumstances are such that it must ...  1892.0
# 10  Telexes should be treated in the same way as i...  1983.0
# 11  Although Mrs Ts promise was not in any sense e...  1842.0
# 12  Under their contracts of employment, the crew ...  1809.0
# 13                                                NaN  1994.0
# 14  Whether parties intended their agreement to be...  2002.0
# 15  Intention inferred from the commercial nature ...  1976.0
# 16  the advertisement was unlike the one in Partri...  1893.0
# 17  P was not a party to the contract (which was h...  1833.0
# 18  Mrs Cs signature might suggest that she was a ...  1967.0
# 19  L signed the document. A reasonable person wou...  1934.0
# 20  Applying the LEstrange v Graucob ratio: The re...  1952.0
# 21  Timing requirement, Offer: issue of the ticket...  1965.0
# 22  Knowledge/notice requirement (requirement met)...  1949.0
# 23      because of the importance of the oral promise  1960.0
# 24  The seller had no special knowledge or experti...  1957.0
# 25  language used: the statement is expressed as a...  1977.0
# 26  A party that has legitimate concerns about the...  1979.0
# 27  As the contract included an implied obligation...  1996.0
# 28                                                NaN  1990.0
# 29  This is because most people who wore the under...  1933.0
# ..                                                ...     ...
# 42  MNF decided how to allocate the three licences...  1953.0
# 43  Contractual damages aim to put the non-breachi...  1978.0
# 44  The aim is to put the non-breaching party in t...  2009.0
# 45  A direct loss is a loss that naturally arises ...     NaN
# 46  The loss was not a direct loss: It does not fl...  1854.0
# 47  The parties must have contemplated, when contr...  1951.0
# 48  The general rule is that a plaintiff cannot cl...  1993.0
# 49  The faulty engine could have been repaired or ...  1986.0
# 50  (applying the Tramways test) the promise was a...  1951.0
# 51  The transaction (sale of land) was such that t...  1954.0
# 52  The anticipatory breach related to the entire ...  1853.0
# 53  B was hired to sing at a number of events. Att...  1876.0
# 54  The term was an innominate/intermediate term: ...  1976.0
# 55  Damages are an adequate remedy where ordinary ...  1946.0
# 56  Specific performance will not be ordered if th...  1931.0
# 57  An injunction will not be granted if it has th...  1988.0
# 58  An injunction will not be granted if it has th...  1852.0
# 59  Duress: As conduct amounted to duress (threat ...  1973.0
# 60  Duress: A threat to breach a contractual oblig...  1979.0
# 61  Undue influence? The relationship of devotee/r...  1887.0
# 62  B and J were not in a relationship traditional...  1936.0
# 63  Special disadvantage: the As were at a special...  1983.0
# 64  the person giving the guarantee did not unders...  1988.0
# 65  There was nothing to suggest that the contract...  1950.0
# 66  The contract will be valid unless a common mis...  2003.0
# 67  The word Peerless was meaningless. The word Pe...  1864.0
# 68  T was aware of circumstances that indicated Js...  1983.0
# 69  The representation made by A as to the takings...  1955.0
# 70  The provision imposed a restraint on Ls abilit...  1950.0
# 71  The Water Act prohibited the conduct contempla...  1997.0
#
#                                           description
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3   Minors may be bound to pay a reasonable price ...
# 4    Beneficial can also be enforced against a minor.
# 5                         an offer must be promissory
# 6   an offer must be intended to result in a contr...
# 7                                 invitation to treat
# 8       acceptance must not be subject to a condition
# 9                              postal acceptance rule
# 10                                  acceptance by fax
# 11  the magnitude of the benefit provided is not r...
# 12                           existing legal duty rule
# 13  exception to the past consideration and existi...
# 14           modern approach to determining intention
# 15       intention: commercial or business agreements
# 16                                                NaN
# 17                                            privity
# 18                                            privity
# 19                                   signed documents
# 20                          nature of document signed
# 21                            incorporation by notice
# 22                                                NaN
# 23              partly-written, partly-oral contracts
# 24                        example of a representation
# 25                     example of contractual promise
# 26                 the universal duty of co-operation
# 27                          generic terms: common law
# 28                  example of breach of term implied
# 29                               merchantable quality
# ..                                                ...
# 42                                 fault disqualifies
# 43  damages aim to put the plaintiff in the positi...
# 44  damages aim to put the plaintiff in the same p...
# 45                                        direct loss
# 46                                 consequential loss
# 47                                    wasted expenses
# 48                 damages: stress and disappointment
# 49                                   duty to mitigate
# 50                                  classifying terms
# 51  late performance of a condition. loss of right...
# 52                 anticipatory breach of a condition
# 53                                  classifying terms
# 54                                  classifying terms
# 55           equitable remedies: specific performance
# 56           equitable remedies: specific performance
# 57                    equitable remedies: injunctions
# 58                    equitable remedies: injunctions
# 59                                   duress to person
# 60                              duress: economic harm
# 61       presumption of general controlling influence
# 62             proof of general controlling influence
# 63                             unconscionable dealing
# 64                      third-party unconscionability
# 65                                     common mistake
# 66                                     common mistake
# 67                                     mutual mistake
# 68                                 unilateral mistake
# 69                                  misrepresentation
# 70                                 restraint of trade
# 71                                implied prohibition
#
# [72 rows x 7 columns]

# %%
searchCases(df, "hide")
